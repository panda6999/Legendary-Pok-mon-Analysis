# %%
import pandas as pd
from io import StringIO
import matplotlib.pyplot as plt

# 1. Define the dataset (Embedded Pokémon dataset)
csv_data = """
Name,Type 1,Type 2,HP,Attack,Defense,Sp. Atk,Sp. Def,Speed,Generation,Legendary
Bulbasaur,Grass,Poison,45,49,49,65,65,45,1,False
Ivysaur,Grass,Poison,60,62,63,80,80,60,1,False
Venusaur,Grass,Poison,80,82,83,100,100,80,1,False
Charmander,Fire,,39,52,43,60,50,65,1,False
Charmeleon,Fire,,58,64,58,80,65,80,1,False
Charizard,Fire,Flying,78,84,78,109,85,100,1,False
Mewtwo,Psychic,,106,110,90,154,90,130,1,True
Zapdos,Electric,Flying,90,90,85,125,90,100,1,True
Articuno,Ice,Flying,90,85,100,95,125,85,1,True
Moltres,Fire,Flying,90,100,90,125,85,90,1,True
"""

# 2. Load the dataset
df = pd.read_csv(StringIO(csv_data))

# 3. Display Basic Dataset Information (mimicking notebook output)
print("--- Dataset Content ---")
print(df)
print("\n--- Dataset Info ---")
df.info()

# 4. Legendary vs Non-Legendary Comparison
legendary_stats = df.groupby('Legendary')[['HP','Attack','Defense','Sp. Atk','Sp. Def','Speed']].mean()

print("\n--- Aggregated Stats (Legendary vs Non-Legendary) ---")
print(legendary_stats)

# 5. Visualization: Legendary vs Non-Legendary Stats
legendary_stats.plot(kind='bar', figsize=(10,6))

plt.title('Average Stats: Legendary vs Non-Legendary')
plt.ylabel('Stat Value')
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# --- Dataset Content ---
#          Name    Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 0   Bulbasaur     Grass  Poison   45      49       49       65       65
# 1     Ivysaur     Grass  Poison   60      62       63       80       80
# 2    Venusaur     Grass  Poison   80      82       83      100      100
# 3  Charmander      Fire     NaN   39      52       43       60       50
# 4  Charmeleon      Fire     NaN   58      64       58       80       65
# 5   Charizard      Fire  Flying   78      84       78      109       85
# 6      Mewtwo   Psychic     NaN  106     110       90      154       90
# 7      Zapdos  Electric  Flying   90      90       85      125       90
# 8    Articuno       Ice  Flying   90      85      100       95      125
# 9     Moltres      Fire  Flying   90     100       90      125       85
#
#    Speed  Generation  Legendary
# 0     45           1      False
# 1     60           1      False
# 2     80           1      False
# ...

# %% [markdown]
# ### Distribution of Attack Stat by Type 1
#
# Let's visualize how the 'Attack' stat is distributed across different 'Type 1' categories using a box plot. This will show us the median, quartiles, and potential outliers for Attack within each Pokémon type.

# %%
plt.figure(figsize=(12, 7))
sns.boxplot(x='Type 1', y='Attack', data=df, palette='viridis')
plt.title('Attack Stat Distribution by Type 1')
plt.xlabel('Pokémon Type 1')
plt.ylabel('Attack Stat')
plt.grid(axis='y', alpha=0.75)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3785325616.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Type 1', y='Attack', data=df, palette='viridis')

# %% [markdown]
# ### Distribution of the Attack Stat
#
# Let's visualize the distribution of the 'Attack' stat using a histogram to see how its values are spread across the Pokémon.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Attack'], bins=5, kde=True)
plt.title('Distribution of Attack Stat')
plt.xlabel('Attack')
plt.ylabel('Number of Pokémon')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# ### Distribution of a Stat: HP
#
# Let's visualize the distribution of a key stat, for example, 'HP', using a histogram. This will show us how frequently different HP values occur in our dataset.

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.histplot(df['HP'], bins=5, kde=True)
plt.title('Distribution of HP Stat')
plt.xlabel('HP')
plt.ylabel('Number of Pokémon')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# ### Relationship Between Attack and Defense
#
# Now, let's look at the relationship between two different stats, like 'Attack' and 'Defense', using a scatter plot. This can help us identify any correlations or patterns.

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.scatterplot(x='Attack', y='Defense', hue='Legendary', data=df, s=100, alpha=0.7)
plt.title('Attack vs Defense Stats (Legendary vs Non-Legendary)')
plt.xlabel('Attack')
plt.ylabel('Defense')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()
